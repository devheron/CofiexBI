# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../database/db.sqlite')

df = pd.read_sql("SELECT * FROM projetos", conn)

conn.close()





## okoioiooioifsofi

df.head()
# Out:
# todos os dados lidos

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../database/db.sqlite')

tabelas = pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)

conn.close()

print(tabelas)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Ver tabelas - estrutura do banco
# ----> 2 pd.read_sql("SELECT name FROM sqlite_master WHERE type='table';", conn)
#       4 print("Tabelas:")
#       5 print(tabelas)
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
# ...

# %%
# Ver estrutura da tabela ( Coluans e tipos ) 
pd.read_sql("PRAGMA table_info(projetos);", conn)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Ver estrutura da tabela ( Coluans e tipos )
# ----> 2 pd.read_sql("PRAGMA table_info(projetos);", conn)
#       4 conn.close()
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:708, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     706 with pandasSQL_builder(con) as pandas_sql:
#     707     if isinstance(pandas_sql, SQLiteDatabase):
# --> 708         return pandas_sql.read_query(
#     709             sql,
#     710             index_col=index_col,
#     711             params=params,
#     712             coerce_float=coerce_float,
#     713             parse_dates=parse_dates,
#     714             chunksize=chunksize,
#     715             dtype_backend=dtype_backend,
#     716             dtype=dtype,
#     717         )
# ...
