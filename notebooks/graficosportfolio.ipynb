# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/processed/cofiex_dadostratados.csv')

df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2974 entries, 0 to 2973
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   cdCartaConsulta             2974 non-null   int64
#  1   nmProjeto                   2974 non-null   object
#  2   sgProjeto                   2904 non-null   object
#  3   nmSetor                     2974 non-null   object
#  4   nmSujeito                   2974 non-null   object
#  5   Regiao                      2974 non-null   object
#  6   nmUnidadeFederal            2968 non-null   object
#  7   nmAbrangenciaNacional       2974 non-null   object
#  8   TipoFinanciamento           2974 non-null   object
#  9   sgFonte                     2973 non-null   object
#  10  VlDolar                     2974 non-null   float64
#  11  CpVlDolar                   2974 non-null   object
#  12  sgMoeda                     2974 non-null   object
# ...

# %%
#Valor total por regiao
df.groupby('Regiao')['VlDolar'].sum().sort_values(ascending=False)
# Out:
# Regiao
# Nacional        1.290572e+11
# Sudeste         9.353520e+10
# Nordeste        3.603318e+10
# Sul             2.803527e+10
# Norte           1.470369e+10
# Centro Oeste    1.391186e+10
# Name: VlDolar, dtype: float64

# %%
# Grafico por região
import matplotlib.pyplot as plt

df.groupby('Regiao')['VlDolar'].sum().sort_values().plot(kind='barh')

plt.title('Valor Total por Região')
plt.xlabel('Valor em Dólar')
plt.ylabel('Região')
plt.show()

# %%
# Projetos por ano
df['ano_recebimento'].value_counts().sort_index()
# Out:
# ano_recebimento
# 1940    377
# 1989      1
# 1990     78
# 1991     49
# 1992     58
# 1993     26
# 1994     18
# 1995     76
# 1996     64
# 1997     56
# 1998     97
# 1999     85
# 2000     65
# 2001     74
# 2002     51
# 2003     97
# 2004     98
# 2005    131
# 2006    143
# 2007     99
# 2008    133
# 2009     96
# 2010     71
# 2011     69
# 2012     52
# 2013     63
# 2014     37
# 2015     29
# 2016     31
# 2017     84
# 2018     67
# 2019     71
# 2020     54
# 2021     64
# 2022     78
# 2023     85
# 2024    147
# Name: count, dtype: int64

# %%
#Grafico temporal
df['ano_recebimento'].value_counts().sort_index().plot()

plt.title('Projetos por Ano')
plt.xlabel('Ano')
plt.ylabel('Quantidade')
plt.show()

# %%
# Top10 projetos
df[['nmProjeto', 'VlDolar']].sort_values(by='VlDolar', ascending=False).head(10)
# Out:
#                                               nmProjeto       VlDolar
# 2907  PROJETO F-X2  AQUISIÇÃO DE AERONAVES DE CAÇA E...  5.734219e+09
# 2872  PROGRAMA DE DESENVOLVIMENTO DE SUBMARINOS - PR...  5.558206e+09
# 2209                              REFINARIA DO MARANHÃO  4.000000e+09
# 2879  AQUISIÇÃO DE HELICÓPTEROS DE MÉDIO PORTE PARA ...  2.580180e+09
# 2601              PROGRAMA DE REFORMA E PROTEÇÃO SOCIAL  2.200000e+09
# 231   PROJETO CONSTRUÇÃO, MONTAGEM E COMISSIONAMENTO...  2.100000e+09
# 2356  CORREDOR DE TRANSPORTE MULTIMODAL CENTRO-NORTE...  1.848000e+09
# 2972           XINGU RIO TRANSMISSORA DE ENERGIA - XRTE  1.818991e+09
# 168           SANEAMENTO E MEIO-AMB. NA AREADO MERCOSUL  1.760347e+09
# 1463                                  FERROVIA PARAENSE  1.650514e+09

# %%
# Projetos por região
df['Regiao'].value_counts().plot(kind='bar')
plt.title('Projetos por Região')
plt.show()

# %%
# Top setores
df['nmSetor'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Setores')
plt.xticks(rotation=45)
plt.show()

# %%
# Evolução no tempo
df['ano_recebimento'].value_counts().sort_index().plot()
plt.title('Projetos por Ano')
plt.show()

# %%
# Valores
df['VlDolar'].plot(kind='hist', bins=30)
plt.title('Distribuição de Valores (USD)')
plt.show()

# %%
# Tipo financiamento
df['TipoFinanciamento'].value_counts().plot(kind='bar')
plt.title('Tipos de Financiamento')
plt.show()
